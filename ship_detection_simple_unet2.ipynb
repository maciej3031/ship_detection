# %%
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.morphology import binary_opening, disk, label
from skimage.segmentation import mark_boundaries
from skimage.util import montage
from sklearn.metrics import fbeta_score
from sklearn.model_selection import train_test_split

import keras
import keras.backend as K
import pandas as pd
import tensorflow as tf
from keras import layers, models
from keras.callbacks import (Callback, EarlyStopping, LearningRateScheduler,
                             ModelCheckpoint, ReduceLROnPlateau)
from keras.layers import Dense
from keras.losses import binary_crossentropy
from keras.models import Sequential
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.test_utils import get_test_data, keras_test
from tqdm import tqdm

import gc; gc.enable() # memory is tight

montage_rgb = lambda x: np.stack([montage(x[:, :, :, i]) for i in range(x.shape[3])], -1)


print(os.listdir("input"))
# Out:
# ['test_ship_segmentations.csv', 'sample_submission.csv', 'train_ship_segmentations.csv', 'test', 'train']

# %%
INPUT_DIR = "input"
CHECKPOINTS_DIR = 'checkpoints'
TRAIN_DIR = os.path.join(INPUT_DIR, "train")
TEST_DIR = os.path.join(INPUT_DIR,"test")
WEIGHT_PATH = os.path.join(CHECKPOINTS_DIR, "simple_unet2_weights.best.hdf5")
MODEL_NAME = 'simple_unet2'
FULL_RES_MODEL_NAME = 'simple_unet2_full_res'

AUGMENT_BRIGHTNESS = False
GAUSSIAN_NOISE = 0.1

DEFAULT_THRESHOLDS = [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
VALID_IMG_COUNT = 1000
IMG_SCALING = (2,2)
BATCH_SIZE = 50
MAX_TRAIN_STEPS = 20
MAX_TRAIN_EPOCHS = 99

# %%
df = pd.read_csv(os.path.join(INPUT_DIR, "train_ship_segmentations.csv"))
df.head()
# Out:
#          ImageId                                      EncodedPixels
# 0  00003e153.jpg                                                NaN
# 1  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 2  00021ddc3.jpg  101361 1 102128 3 102896 4 103663 6 104430 9 1...
# 3  00021ddc3.jpg  95225 2 95992 5 96760 7 97527 9 98294 9 99062 ...
# 4  00021ddc3.jpg  74444 4 75212 4 75980 4 76748 4 77517 3 78285 ...

# %% [markdown]
# # 1. Training dataset stats

# %%
# 1. Use only image with ships
# 2. Pretrained U-net CNN model, ResNet, Ternaus on ImageNet
# 3. Try to learn on 768x768 images
# 3. Cross validation training with parameters tuning

# %%
num_of_all_images = len(df.drop_duplicates('ImageId'))
num_of_no_ships_images = sum(pd.isnull(df['EncodedPixels']))
num_of_all_rows = len(df)

print("Number of images: {}".format(num_of_all_images))
print("Number of images without ships: {}".format(num_of_no_ships_images))
print("Number of images with ships: {}".format(num_of_all_images - num_of_no_ships_images))
print("Number of ships: {}".format(num_of_all_rows - num_of_no_ships_images))

# We can consider that dataset is not balanced enough
# Out:
# Number of images: 104070
# Number of images without ships: 75000
# Number of images with ships: 29070
# Number of ships: 56030

# %% [markdown]
# # 2. RLE encoding and decoding

# %%
def rle_decode(rle_mask, shape=(768,768)):
    '''
    rle_mask: run-length encoded string
    img: image coresponding to rle_mask
    Returns numpy array, 1 - mask, 0 - background
    '''
    rle_mask_list = rle_mask.split(" ")
    starts, lengths = [np.array(pair, dtype=int) for pair in (rle_mask_list[::2], rle_mask_list[1::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction

def multi_rle_encode(img, **kwargs):
    '''
    Encode connected regions as separated masks
    '''
    labels = label(img)
    if img.ndim > 2:
        return [rle_encode(np.sum(labels==k, axis=2), **kwargs) for k in np.unique(labels[labels>0])]
    else:
        return [rle_encode(labels==k, **kwargs) for k in np.unique(labels[labels>0])]

def rle_encode(img, min_max_threshold=1e-3, max_mean_threshold=None):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run-length encoded string
    '''
    if np.max(img) < min_max_threshold:
        return '' ## no need to encode if it's all zeros
    if max_mean_threshold and np.mean(img) > max_mean_threshold:
        return '' ## ignore overfilled mask
    pixels = img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def masks_as_image(in_mask_list):
    # Take the individual ship masks and create a single mask array for all ships
    all_masks = np.zeros((768, 768), dtype = np.uint8)
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks |= rle_decode(mask)
    return all_masks

def masks_as_color(in_mask_list):
    # Take the individual ship masks and create a color mask array for each ships
    all_masks = np.zeros((768, 768), dtype = np.float)
    scale = lambda x: (len(in_mask_list)+x+1) / (len(in_mask_list)*2) ## scale the heatmap image to shift 
    for i,mask in enumerate(in_mask_list):
        if isinstance(mask, str):
            all_masks[:,:] += scale(i) * rle_decode(mask)
    return all_masks

# %% [markdown]
# ## Check if above functions work properly

# %%
df.loc[df['ImageId'] =="00021ddc3.jpg"]
# Out:
#           ImageId                                      EncodedPixels
# 2   00021ddc3.jpg  101361 1 102128 3 102896 4 103663 6 104430 9 1...
# 3   00021ddc3.jpg  95225 2 95992 5 96760 7 97527 9 98294 9 99062 ...
# 4   00021ddc3.jpg  74444 4 75212 4 75980 4 76748 4 77517 3 78285 ...
# 5   00021ddc3.jpg  150423 2 151190 3 151958 3 152726 4 153495 3 1...
# 6   00021ddc3.jpg  139644 2 140408 6 141174 9 141942 9 142711 6 1...
# 7   00021ddc3.jpg  86727 2 87493 4 88261 4 89030 3 89798 4 90566 ...
# 8   00021ddc3.jpg  74441 3 75207 5 75975 5 76743 5 77511 5 78280 ...
# 9   00021ddc3.jpg  75972 3 76738 5 77506 5 78274 5 79042 6 79811 ...
# 10  00021ddc3.jpg  108287 1 109054 3 109821 4 110588 5 111356 5 1...

# %%
# fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize = (30, 10))
# rle_0 = df.query('ImageId=="00021ddc3.jpg"')['EncodedPixels']
# img_0 = masks_as_image(rle_0)
# ax1.imshow(img_0)
# ax1.set_title('Mask as image')
# rle_1 = multi_rle_encode(img_0)
# img_1 = masks_as_image(rle_1)
# ax2.imshow(img_1)
# ax2.set_title('Re-encoded')
# img_2 = masks_as_color(rle_0)
# ax3.imshow(img_2)
# ax3.set_title('Masks in colors')
# img_3 = masks_as_color(rle_1)
# ax4.imshow(img_3)
# ax4.set_title('Re-encoded in colors')

# img_4 = cv2.imread(os.path.join(TRAIN_DIR, '00021ddc3.jpg'))
# ax5.imshow(img_4)
# ax5.set_title('Real image')


# print('Check Decoding->Encoding',
#       'RLE_0:', len(rle_0), '->',
#       'RLE_1:', len(rle_1))
# print(np.sum(img_0 - img_1), 'error')

# %% [markdown]
# # 3. Split to training and validation datasets

# %%
df['ships'] = df['EncodedPixels'].map(lambda c_row: 1 if isinstance(c_row, str) else 0)
unique_img_ids = df.groupby('ImageId').agg({'ships': 'sum'}).reset_index()
unique_img_ids['has_ship'] = unique_img_ids['ships'].map(lambda x: 1.0 if x>0 else 0.0)

# some files are too small/corrupt
unique_img_ids['file_size_kb'] = unique_img_ids['ImageId'].map(lambda c_img_id: os.stat(os.path.join(TRAIN_DIR, c_img_id)).st_size/1024)
unique_img_ids = unique_img_ids[unique_img_ids['file_size_kb'] > 50] # keep only +50kb files
unique_img_ids['file_size_kb'].hist()
df.drop(['ships'], axis=1, inplace=True)
unique_img_ids.sample(7)
# Out:
#              ImageId  ships  has_ship  file_size_kb
# 88325  d96bbab45.jpg      0       0.0    128.939453
# 2552   061e5fc37.jpg      0       0.0    148.837891
# 63236  9b489012f.jpg      0       0.0    125.371094
# 67851  a6dc5df6e.jpg      0       0.0    101.290039
# 92762  e4468e171.jpg      0       0.0     95.087891
# 24560  3c7908602.jpg      0       0.0    148.884766
# 37222  5bb0ae606.jpg      0       0.0    161.222656

# %% [markdown]
# ## Ships number histogram

# %%
unique_img_ids['ships'].hist(bins=unique_img_ids['ships'].max())

# %% [markdown]
# ## Drop empty images

# %%
# SAMPLES_PER_GROUP = 10000
# balanced_train_df = unique_img_ids.groupby('ships').apply(lambda x: x.sample(SAMPLES_PER_GROUP) if len(x) > SAMPLES_PER_GROUP else x)
balanced_train_df = unique_img_ids[unique_img_ids.ships != 0]

balanced_train_df['ships'].hist(bins=balanced_train_df['ships'].max()+1)
print(balanced_train_df.shape[0], 'masks')
# Out:
# 28693 masks

# %%
train_ids, valid_ids = train_test_split(balanced_train_df, test_size=VALID_IMG_COUNT, stratify = balanced_train_df['ships'])
train_df = pd.merge(df, train_ids)
valid_df = pd.merge(df, valid_ids)
print(train_df.shape[0], 'training masks')
print(valid_df.shape[0], 'validation masks')
train_df.head()
# Out:
# 53459 training masks
# 1930 validation masks
#          ImageId                                      EncodedPixels  ships  \
# 0  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...      1
# 1  00021ddc3.jpg  101361 1 102128 3 102896 4 103663 6 104430 9 1...      9
# 2  00021ddc3.jpg  95225 2 95992 5 96760 7 97527 9 98294 9 99062 ...      9
# 3  00021ddc3.jpg  74444 4 75212 4 75980 4 76748 4 77517 3 78285 ...      9
# 4  00021ddc3.jpg  150423 2 151190 3 151958 3 152726 4 153495 3 1...      9
#
#    has_ship  file_size_kb
# 0       1.0    147.625977
# 1       1.0    242.910156
# 2       1.0    242.910156
# 3       1.0    242.910156
# 4       1.0    242.910156

# %%
def make_image_gen(in_df, batch_size=BATCH_SIZE, img_scaling=IMG_SCALING):
    all_batches = list(in_df.groupby('ImageId'))
    out_rgb = []
    out_mask = []
    while True:
        np.random.shuffle(all_batches)
        for c_img_id, c_masks in all_batches:
            rgb_path = os.path.join(TRAIN_DIR, c_img_id)
            c_img = cv2.imread(rgb_path)
            c_mask = np.expand_dims(masks_as_image(c_masks['EncodedPixels'].values), -1)
            if IMG_SCALING is not None:
                c_img = c_img[::img_scaling[0], ::img_scaling[1]]
                c_mask = c_mask[::img_scaling[0], ::img_scaling[1]]
            out_rgb += [c_img]
            out_mask += [c_mask]
            if len(out_rgb)>=batch_size:
                yield np.stack(out_rgb, 0)/255.0, np.stack(out_mask, 0)
                out_rgb, out_mask=[], []

# %% [markdown]
# ## Create validation dataset

# %%
valid_gen = make_image_gen(valid_df, VALID_IMG_COUNT)
valid_x, valid_y = next(valid_gen)
print('x', valid_x.shape, valid_x.min(), valid_x.max())
print('y', valid_y.shape, valid_y.min(), valid_y.max())
# Out:
# x (1000, 384, 384, 3) 0.0 1.0
# y (1000, 384, 384, 1) 0 1

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (30, 10))
batch_rgb = montage_rgb(valid_x[:9])
batch_seg = montage(valid_y[:9, :, :, 0])
ax1.imshow(batch_rgb)
ax1.set_title('Images')
ax2.imshow(batch_seg)
ax2.set_title('Segmentations')
ax3.imshow(mark_boundaries(batch_rgb, batch_seg.astype(int)))
ax3.set_title('Outlined Ships')
# Out:
# Text(0.5,1,'Outlined Ships')

# %% [markdown]
# ## Data augmentation

# %%
dg_args = dict(rotation_range = 45, 
               width_shift_range = 0.1, 
               height_shift_range = 0.1, 
               shear_range = 0.01,
               zoom_range = [0.9, 1.25],  
               horizontal_flip = True, 
               vertical_flip = True,
               fill_mode = 'reflect',
               data_format = 'channels_last')

# brightness can be problematic since it seems to change the labels differently from the images 
if AUGMENT_BRIGHTNESS:
    dg_args['brightness_range'] = [0.5, 1.5]
image_gen = ImageDataGenerator(**dg_args)

if AUGMENT_BRIGHTNESS:
    dg_args.pop('brightness_range')
label_gen = ImageDataGenerator(**dg_args)

def create_aug_gen(in_gen, seed = None):
    np.random.seed(seed if seed is not None else np.random.choice(range(9999)))
    for in_x, in_y in in_gen:
        seed = np.random.choice(range(9999))
        # keep the seeds syncronized otherwise the augmentation to the images is different from the masks
        g_x = image_gen.flow(255*in_x, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)
        g_y = label_gen.flow(in_y, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)

        yield next(g_x)/255.0, next(g_y)

# %%
gc.collect()
# Out:
# 5372

# %% [markdown]
# # 4. Model

# %%
# Build U-Net model

inp = layers.Input(valid_x.shape[1:], name = 'RGB_Input')

c1 = layers.Conv2D(8, (3, 3), padding='same') (in1)
c1 = layers.BatchNormalization() (c1)
c1 = layers.Activation('relu') (c1)
c2 = layers.Conv2D(8, (3, 3), padding='same') (c1)
c2 = layers.BatchNormalization() (c2)
c2 = layers.Activation('relu') (c2)
d1 = layers.Dropout(0.1)(c2)

c3 = layers.Conv2D(16, (3, 3), padding='same') (d1)
c3 = layers.BatchNormalization() (c3)
c3 = layers.Activation('relu') (c3)
c4 = layers.Conv2D(16, (3, 3), padding='same') (c3)
c4 = layers.BatchNormalization() (c4)
c4 = layers.Activation('relu') (c4)
d2 = layers.Dropout(0.1)(c4)

p1 = layers.MaxPooling2D((3, 3), 2) (d2)

c5 = layers.Conv2D(32, (3, 3), padding='same') (p1)
c5 = layers.BatchNormalization() (c5)
c5 = layers.Activation('relu') (c5)
c6 = layers.Conv2D(32, (3, 3), padding='same') (c5)
c6 = layers.BatchNormalization() (c6)
c6 = layers.Activation('relu') (c6)
d3 = layers.Dropout(0.1)(c6)

p2 = layers.MaxPooling2D((3, 3), 2) (d3)

c7 = layers.Conv2D(64, (3, 3), padding='same') (p2)
c7 = layers.BatchNormalization() (c7)
c7= layers.Activation('relu') (c7)
c8 = layers.Conv2D(64, (3, 3), padding='same') (c7)
c8 = layers.BatchNormalization() (c8)
c8 = layers.Activation('relu') (c8)
d4 = layers.Dropout(0.1)(c8)

u1 = layers.Conv2DTranspose(32, (6, 6), strides=(2, 2), padding='same', use_bias=True)(d4)
u1 = layers.concatenate([u1, d3])

c9 = layers.Conv2D(32, (3, 3), padding='same') (u1)
c9 = layers.BatchNormalization() (c9)
c9 = layers.Activation('relu') (c9)
c10 = layers.Conv2D(32, (3, 3), padding='same') (c9)
c10 = layers.BatchNormalization() (c10)
c10 = layers.Activation('relu') (c10)
d5 = layers.Dropout(0.1)(c10)

u2 = layers.Conv2DTranspose(16, (6, 6), strides=(2, 2), padding='same', use_bias=True)(d5)
u2 = layers.concatenate([u2, d2])

c11 = layers.Conv2D(16, (3, 3), padding='same') (u2)
c11 = layers.BatchNormalization() (c11)
c11 = layers.Activation('relu') (c11)
c12 = layers.Conv2D(16, (3, 3), padding='same') (c11)
c12 = layers.BatchNormalization() (c12)
c12 = layers.Activation('relu') (c12)
d6 = layers.Dropout(0.1)(c12)

c13 = layers.Conv2D(8, (3, 3), padding='same') (d6)
c13 = layers.BatchNormalization() (c13)
c13 = layers.Activation('relu') (c13)
d7 = layers.Dropout(0.1)(c13)
c14 = layers.Conv2D(8, (3, 3), padding='same') (d7)
c14 = layers.BatchNormalization() (c14)
c14 = layers.Activation('relu') (c14)

output = layers.Conv2D(1, (1, 1), activation='sigmoid') (c14)

seg_model = models.Model(inputs=[inp], outputs=[output])
seg_model.summary()

# %%
def kaggle_IoU(y_true, y_pred):
    gc.collect()
    score_list = []
    for thresh in DEFAULT_THRESHOLDS:
        iou = IoU(y_true, y_pred, thresh=thresh)
        score_list.append(iou)

    return K.mean(tf.convert_to_tensor(score_list))

def IoU(y_true, y_pred, thresh=0.5, eps=1e-6):
    y_pred = tf.to_float(tf.to_int32(y_pred > thresh))
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return (intersection + eps) / (union + eps)

def dice_loss(y_true, y_pred, smooth=1.):
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred)
    return 1 - (2.0 * intersection + smooth) / (union + smooth)

def bin_cross_and_IoU(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - 10 * K.log(1 - dice_loss(y_true, y_pred))

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def bce_logdice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

def weighted_bce_loss(y_true, y_pred, weight):
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = weight * (logit_y_pred * (1. - y_true) + 
                     K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    loss = 1. - K.sum(score)
    return loss

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd
    averaged_mask = K.pool2d(y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
    return loss

# %%
checkpoint = ModelCheckpoint(WEIGHT_PATH, monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                                   patience=1, verbose=1, mode='min',
                                   min_delta=0.00001, cooldown=0, min_lr=1e-8)

early = EarlyStopping(monitor="val_loss", mode="min", verbose=2, patience=10)

callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
def fit():
    try:
        seg_model.load_weights(WEIGHT_PATH)
    except OSError:
        print('No file with weights available! Starting from scratch...')
    seg_model.compile(optimizer=Adam(0.001, decay=0.000001), loss=bin_cross_and_IoU, metrics=['binary_accuracy', IoU, kaggle_IoU])
    
    step_count = min(MAX_TRAIN_STEPS, train_df.shape[0]//BATCH_SIZE)
    aug_gen = create_aug_gen(make_image_gen(train_df))
    loss_history = [seg_model.fit_generator(aug_gen,
                                 steps_per_epoch=step_count,
                                 epochs=MAX_TRAIN_EPOCHS,
                                 validation_data=(valid_x, valid_y),
                                 callbacks=callbacks_list,
                                 workers=1)]
    return loss_history

while True:
    loss_history = fit()
    if np.min([mh.history['val_loss'] for mh in loss_history]) < 1.0:
        break
# Out:
# Epoch 1/99
# 20/20 [==============================] - 106s 5s/step - loss: 40.6487 - binary_accuracy: 0.7649 - IoU: 0.0209 - kaggle_IoU: 0.0186 - val_loss: 23.5407 - val_binary_accuracy: 0.9821 - val_IoU: 0.1013 - val_kaggle_IoU: 0.1220
#
# Epoch 00001: val_loss improved from inf to 23.54075, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 2/99
# 20/20 [==============================] - 79s 4s/step - loss: 14.4283 - binary_accuracy: 0.9892 - IoU: 0.1544 - kaggle_IoU: 0.1577 - val_loss: 13.6872 - val_binary_accuracy: 0.9860 - val_IoU: 0.1543 - val_kaggle_IoU: 0.1581
#
# Epoch 00002: val_loss improved from 23.54075 to 13.68718, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 3/99
# 20/20 [==============================] - 84s 4s/step - loss: 11.2708 - binary_accuracy: 0.9917 - IoU: 0.2032 - kaggle_IoU: 0.2034 - val_loss: 11.5450 - val_binary_accuracy: 0.9904 - val_IoU: 0.1953 - val_kaggle_IoU: 0.2014
#
# Epoch 00003: val_loss improved from 13.68718 to 11.54504, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 4/99
# 20/20 [==============================] - 83s 4s/step - loss: 9.2191 - binary_accuracy: 0.9934 - IoU: 0.2614 - kaggle_IoU: 0.2615 - val_loss: 11.7197 - val_binary_accuracy: 0.9876 - val_IoU: 0.2007 - val_kaggle_IoU: 0.2137
#
# Epoch 00004: val_loss did not improve from 11.54504
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 5/99
# 20/20 [==============================] - 84s 4s/step - loss: 8.9412 - binary_accuracy: 0.9927 - IoU: 0.2687 - kaggle_IoU: 0.2692 - val_loss: 9.7420 - val_binary_accuracy: 0.9920 - val_IoU: 0.2557 - val_kaggle_IoU: 0.2629
#
# Epoch 00005: val_loss improved from 11.54504 to 9.74201, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 6/99
# 20/20 [==============================] - 83s 4s/step - loss: 8.4511 - binary_accuracy: 0.9942 - IoU: 0.2867 - kaggle_IoU: 0.2838 - val_loss: 9.7158 - val_binary_accuracy: 0.9916 - val_IoU: 0.2543 - val_kaggle_IoU: 0.2648
#
# Epoch 00006: val_loss improved from 9.74201 to 9.71577, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 7/99
# 20/20 [==============================] - 83s 4s/step - loss: 8.1231 - binary_accuracy: 0.9939 - IoU: 0.2949 - kaggle_IoU: 0.2937 - val_loss: 8.8185 - val_binary_accuracy: 0.9937 - val_IoU: 0.2824 - val_kaggle_IoU: 0.2880
#
# Epoch 00007: val_loss improved from 9.71577 to 8.81846, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 8/99
# 20/20 [==============================] - 83s 4s/step - loss: 7.5386 - binary_accuracy: 0.9948 - IoU: 0.3196 - kaggle_IoU: 0.3173 - val_loss: 9.5760 - val_binary_accuracy: 0.9920 - val_IoU: 0.2587 - val_kaggle_IoU: 0.2661
#
# Epoch 00008: val_loss did not improve from 8.81846
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 9/99
# 20/20 [==============================] - 83s 4s/step - loss: 7.7472 - binary_accuracy: 0.9944 - IoU: 0.3131 - kaggle_IoU: 0.3101 - val_loss: 8.8880 - val_binary_accuracy: 0.9933 - val_IoU: 0.2802 - val_kaggle_IoU: 0.2853
#
# Epoch 00009: val_loss did not improve from 8.81846
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 10/99
# 20/20 [==============================] - 84s 4s/step - loss: 7.8161 - binary_accuracy: 0.9941 - IoU: 0.3096 - kaggle_IoU: 0.3061 - val_loss: 8.8959 - val_binary_accuracy: 0.9932 - val_IoU: 0.2795 - val_kaggle_IoU: 0.2856
#
# Epoch 00010: val_loss did not improve from 8.81846
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 11/99
# 20/20 [==============================] - 83s 4s/step - loss: 8.0786 - binary_accuracy: 0.9941 - IoU: 0.2976 - kaggle_IoU: 0.2932 - val_loss: 8.9306 - val_binary_accuracy: 0.9931 - val_IoU: 0.2785 - val_kaggle_IoU: 0.2854
#
# Epoch 00011: val_loss did not improve from 8.81846
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 12/99
# 20/20 [==============================] - 84s 4s/step - loss: 7.7959 - binary_accuracy: 0.9944 - IoU: 0.3116 - kaggle_IoU: 0.3085 - val_loss: 8.9317 - val_binary_accuracy: 0.9931 - val_IoU: 0.2784 - val_kaggle_IoU: 0.2854
#
# Epoch 00012: val_loss did not improve from 8.81846
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 00012: early stopping
# Epoch 1/99
# 20/20 [==============================] - 91s 5s/step - loss: 12.2496 - binary_accuracy: 0.9879 - IoU: 0.2125 - kaggle_IoU: 0.2146 - val_loss: 10.6423 - val_binary_accuracy: 0.9905 - val_IoU: 0.2256 - val_kaggle_IoU: 0.2402
#
# Epoch 00001: val_loss did not improve from 8.81846
# Epoch 2/99
# 20/20 [==============================] - 78s 4s/step - loss: 7.9237 - binary_accuracy: 0.9939 - IoU: 0.3097 - kaggle_IoU: 0.3083 - val_loss: 9.8212 - val_binary_accuracy: 0.9906 - val_IoU: 0.2397 - val_kaggle_IoU: 0.2536
#
# Epoch 00002: val_loss did not improve from 8.81846
# Epoch 3/99
# 20/20 [==============================] - 78s 4s/step - loss: 8.1851 - binary_accuracy: 0.9941 - IoU: 0.2955 - kaggle_IoU: 0.2940 - val_loss: 8.9763 - val_binary_accuracy: 0.9923 - val_IoU: 0.2658 - val_kaggle_IoU: 0.2744
#
# Epoch 00003: val_loss did not improve from 8.81846
# Epoch 4/99
# 20/20 [==============================] - 78s 4s/step - loss: 8.5956 - binary_accuracy: 0.9936 - IoU: 0.2780 - kaggle_IoU: 0.2786 - val_loss: 9.9701 - val_binary_accuracy: 0.9900 - val_IoU: 0.2371 - val_kaggle_IoU: 0.2469
#
# Epoch 00004: val_loss did not improve from 8.81846
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 5/99
# 20/20 [==============================] - 78s 4s/step - loss: 7.1624 - binary_accuracy: 0.9939 - IoU: 0.3336 - kaggle_IoU: 0.3313 - val_loss: 7.8181 - val_binary_accuracy: 0.9939 - val_IoU: 0.3086 - val_kaggle_IoU: 0.3129
#
# Epoch 00005: val_loss improved from 8.81846 to 7.81811, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 6/99
# 20/20 [==============================] - 78s 4s/step - loss: 6.9113 - binary_accuracy: 0.9943 - IoU: 0.3425 - kaggle_IoU: 0.3418 - val_loss: 8.0328 - val_binary_accuracy: 0.9934 - val_IoU: 0.3008 - val_kaggle_IoU: 0.3057
#
# Epoch 00006: val_loss did not improve from 7.81811
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 7/99
# 20/20 [==============================] - 78s 4s/step - loss: 7.3226 - binary_accuracy: 0.9942 - IoU: 0.3293 - kaggle_IoU: 0.3276 - val_loss: 7.8955 - val_binary_accuracy: 0.9936 - val_IoU: 0.3060 - val_kaggle_IoU: 0.3106
#
# Epoch 00007: val_loss did not improve from 7.81811
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 8/99
# 20/20 [==============================] - 78s 4s/step - loss: 7.0360 - binary_accuracy: 0.9943 - IoU: 0.3430 - kaggle_IoU: 0.3405 - val_loss: 7.8771 - val_binary_accuracy: 0.9937 - val_IoU: 0.3067 - val_kaggle_IoU: 0.3113
#
# Epoch 00008: val_loss did not improve from 7.81811
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 9/99
# 20/20 [==============================] - 78s 4s/step - loss: 7.4224 - binary_accuracy: 0.9942 - IoU: 0.3244 - kaggle_IoU: 0.3227 - val_loss: 7.8680 - val_binary_accuracy: 0.9937 - val_IoU: 0.3070 - val_kaggle_IoU: 0.3116
#
# Epoch 00009: val_loss did not improve from 7.81811
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 10/99
# 20/20 [==============================] - 78s 4s/step - loss: 6.6665 - binary_accuracy: 0.9945 - IoU: 0.3548 - kaggle_IoU: 0.3519 - val_loss: 7.8705 - val_binary_accuracy: 0.9937 - val_IoU: 0.3069 - val_kaggle_IoU: 0.3116
#
# Epoch 00010: val_loss did not improve from 7.81811
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 00010: early stopping
# Epoch 1/99
# 20/20 [==============================] - 107s 5s/step - loss: 8.4128 - binary_accuracy: 0.9933 - IoU: 0.2900 - kaggle_IoU: 0.2901 - val_loss: 7.9815 - val_binary_accuracy: 0.9948 - val_IoU: 0.3063 - val_kaggle_IoU: 0.3055
#
# Epoch 00001: val_loss did not improve from 7.81811
# Epoch 2/99
# 20/20 [==============================] - 60s 3s/step - loss: 8.1520 - binary_accuracy: 0.9932 - IoU: 0.2948 - kaggle_IoU: 0.2941 - val_loss: 7.3513 - val_binary_accuracy: 0.9947 - val_IoU: 0.3257 - val_kaggle_IoU: 0.3286
# Epoch 00002: val_loss improved from 7.81811 to 7.35129, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 3/99
# 20/20 [==============================] - 76s 4s/step - loss: 6.1454 - binary_accuracy: 0.9947 - IoU: 0.3822 - kaggle_IoU: 0.3811 - val_loss: 7.5896 - val_binary_accuracy: 0.9936 - val_IoU: 0.3180 - val_kaggle_IoU: 0.3217
#
# Epoch 00003: val_loss did not improve from 7.35129
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 4/99
# 20/20 [==============================] - 77s 4s/step - loss: 7.2419 - binary_accuracy: 0.9945 - IoU: 0.3325 - kaggle_IoU: 0.3325 - val_loss: 7.7624 - val_binary_accuracy: 0.9931 - val_IoU: 0.3104 - val_kaggle_IoU: 0.3134
#
# Epoch 00004: val_loss did not improve from 7.35129
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 5/99
# 20/20 [==============================] - 75s 4s/step - loss: 6.9998 - binary_accuracy: 0.9939 - IoU: 0.3403 - kaggle_IoU: 0.3402 - val_loss: 7.1038 - val_binary_accuracy: 0.9944 - val_IoU: 0.3374 - val_kaggle_IoU: 0.3382
#
# Epoch 00005: val_loss improved from 7.35129 to 7.10380, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 6/99
# 20/20 [==============================] - 76s 4s/step - loss: 6.7371 - binary_accuracy: 0.9950 - IoU: 0.3534 - kaggle_IoU: 0.3519 - val_loss: 7.2723 - val_binary_accuracy: 0.9939 - val_IoU: 0.3304 - val_kaggle_IoU: 0.3330
#
# Epoch 00006: val_loss did not improve from 7.10380
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 7/99
# 20/20 [==============================] - 78s 4s/step - loss: 6.1995 - binary_accuracy: 0.9948 - IoU: 0.3797 - kaggle_IoU: 0.3789 - val_loss: 7.2230 - val_binary_accuracy: 0.9940 - val_IoU: 0.3325 - val_kaggle_IoU: 0.3349
#
# Epoch 00007: val_loss did not improve from 7.10380
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 8/99
# 20/20 [==============================] - 75s 4s/step - loss: 6.5324 - binary_accuracy: 0.9942 - IoU: 0.3634 - kaggle_IoU: 0.3634 - val_loss: 7.2141 - val_binary_accuracy: 0.9940 - val_IoU: 0.3329 - val_kaggle_IoU: 0.3353
#
# Epoch 00008: val_loss did not improve from 7.10380
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 9/99
# 20/20 [==============================] - 77s 4s/step - loss: 6.6142 - binary_accuracy: 0.9946 - IoU: 0.3592 - kaggle_IoU: 0.3585 - val_loss: 7.2058 - val_binary_accuracy: 0.9940 - val_IoU: 0.3333 - val_kaggle_IoU: 0.3356
#
# Epoch 00009: val_loss did not improve from 7.10380
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 10/99
# 20/20 [==============================] - 77s 4s/step - loss: 6.9176 - binary_accuracy: 0.9948 - IoU: 0.3460 - kaggle_IoU: 0.3459 - val_loss: 7.2051 - val_binary_accuracy: 0.9940 - val_IoU: 0.3333 - val_kaggle_IoU: 0.3356
#
# Epoch 00010: val_loss did not improve from 7.10380
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 00010: early stopping
# Epoch 1/99
# 20/20 [==============================] - 87s 4s/step - loss: 7.6622 - binary_accuracy: 0.9936 - IoU: 0.3168 - kaggle_IoU: 0.3163 - val_loss: 7.3683 - val_binary_accuracy: 0.9938 - val_IoU: 0.3264 - val_kaggle_IoU: 0.3322
#
# Epoch 00001: val_loss did not improve from 7.10380
# Epoch 2/99
# 20/20 [==============================] - 74s 4s/step - loss: 6.6700 - binary_accuracy: 0.9943 - IoU: 0.3562 - kaggle_IoU: 0.3559 - val_loss: 6.9503 - val_binary_accuracy: 0.9948 - val_IoU: 0.3429 - val_kaggle_IoU: 0.3436
#
# Epoch 00002: val_loss improved from 7.10380 to 6.95028, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 3/99
# 20/20 [==============================] - 76s 4s/step - loss: 6.4720 - binary_accuracy: 0.9944 - IoU: 0.3639 - kaggle_IoU: 0.3632 - val_loss: 7.1838 - val_binary_accuracy: 0.9940 - val_IoU: 0.3354 - val_kaggle_IoU: 0.3383
#
# Epoch 00003: val_loss did not improve from 6.95028
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 4/99
# 20/20 [==============================] - 74s 4s/step - loss: 6.8722 - binary_accuracy: 0.9944 - IoU: 0.3507 - kaggle_IoU: 0.3500 - val_loss: 6.7942 - val_binary_accuracy: 0.9943 - val_IoU: 0.3524 - val_kaggle_IoU: 0.3550
#
# Epoch 00004: val_loss improved from 6.95028 to 6.79418, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 5/99
# 20/20 [==============================] - 75s 4s/step - loss: 6.5323 - binary_accuracy: 0.9944 - IoU: 0.3661 - kaggle_IoU: 0.3657 - val_loss: 6.5217 - val_binary_accuracy: 0.9950 - val_IoU: 0.3641 - val_kaggle_IoU: 0.3647
#
# Epoch 00005: val_loss improved from 6.79418 to 6.52166, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 6/99
# 20/20 [==============================] - 75s 4s/step - loss: 6.2441 - binary_accuracy: 0.9948 - IoU: 0.3755 - kaggle_IoU: 0.3745 - val_loss: 6.5496 - val_binary_accuracy: 0.9950 - val_IoU: 0.3629 - val_kaggle_IoU: 0.3638
#
# Epoch 00006: val_loss did not improve from 6.52166
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 7/99
# 20/20 [==============================] - 76s 4s/step - loss: 6.2923 - binary_accuracy: 0.9948 - IoU: 0.3733 - kaggle_IoU: 0.3722 - val_loss: 6.7137 - val_binary_accuracy: 0.9945 - val_IoU: 0.3552 - val_kaggle_IoU: 0.3576
#
# Epoch 00007: val_loss did not improve from 6.52166
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 8/99
# 20/20 [==============================] - 78s 4s/step - loss: 6.1400 - binary_accuracy: 0.9945 - IoU: 0.3812 - kaggle_IoU: 0.3804 - val_loss: 6.6833 - val_binary_accuracy: 0.9946 - val_IoU: 0.3566 - val_kaggle_IoU: 0.3589
#
# Epoch 00008: val_loss did not improve from 6.52166
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 9/99
# 20/20 [==============================] - 78s 4s/step - loss: 6.2781 - binary_accuracy: 0.9945 - IoU: 0.3750 - kaggle_IoU: 0.3734 - val_loss: 6.6854 - val_binary_accuracy: 0.9946 - val_IoU: 0.3564 - val_kaggle_IoU: 0.3587
#
# Epoch 00009: val_loss did not improve from 6.52166
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 10/99
# 20/20 [==============================] - 78s 4s/step - loss: 6.4697 - binary_accuracy: 0.9948 - IoU: 0.3678 - kaggle_IoU: 0.3671 - val_loss: 6.6854 - val_binary_accuracy: 0.9946 - val_IoU: 0.3564 - val_kaggle_IoU: 0.3587
#
# Epoch 00010: val_loss did not improve from 6.52166
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 00010: early stopping
# Epoch 1/99
# 20/20 [==============================] - 91s 5s/step - loss: 6.8022 - binary_accuracy: 0.9945 - IoU: 0.3552 - kaggle_IoU: 0.3543 - val_loss: 6.5049 - val_binary_accuracy: 0.9947 - val_IoU: 0.3646 - val_kaggle_IoU: 0.3682
#
# Epoch 00001: val_loss improved from 6.52166 to 6.50491, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 2/99
# 20/20 [==============================] - 77s 4s/step - loss: 7.2828 - binary_accuracy: 0.9946 - IoU: 0.3315 - kaggle_IoU: 0.3308 - val_loss: 7.0020 - val_binary_accuracy: 0.9958 - val_IoU: 0.3428 - val_kaggle_IoU: 0.3408
#
# Epoch 00002: val_loss did not improve from 6.50491
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 3/99
# 20/20 [==============================] - 77s 4s/step - loss: 6.5378 - binary_accuracy: 0.9951 - IoU: 0.3609 - kaggle_IoU: 0.3613 - val_loss: 6.8676 - val_binary_accuracy: 0.9942 - val_IoU: 0.3496 - val_kaggle_IoU: 0.3534
#
# Epoch 00003: val_loss did not improve from 6.50491
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 4/99
# 20/20 [==============================] - 77s 4s/step - loss: 6.4579 - binary_accuracy: 0.9945 - IoU: 0.3701 - kaggle_IoU: 0.3708 - val_loss: 6.4772 - val_binary_accuracy: 0.9949 - val_IoU: 0.3671 - val_kaggle_IoU: 0.3695
#
# Epoch 00004: val_loss improved from 6.50491 to 6.47723, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 5/99
# 20/20 [==============================] - 77s 4s/step - loss: 6.2834 - binary_accuracy: 0.9945 - IoU: 0.3770 - kaggle_IoU: 0.3753 - val_loss: 6.4210 - val_binary_accuracy: 0.9949 - val_IoU: 0.3701 - val_kaggle_IoU: 0.3727
# Epoch 00005: val_loss improved from 6.47723 to 6.42096, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 6/99
# 20/20 [==============================] - 79s 4s/step - loss: 6.2296 - binary_accuracy: 0.9946 - IoU: 0.3783 - kaggle_IoU: 0.3779 - val_loss: 6.3189 - val_binary_accuracy: 0.9950 - val_IoU: 0.3750 - val_kaggle_IoU: 0.3774
#
# Epoch 00006: val_loss improved from 6.42096 to 6.31893, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 7/99
# 20/20 [==============================] - 80s 4s/step - loss: 6.3061 - binary_accuracy: 0.9947 - IoU: 0.3755 - kaggle_IoU: 0.3758 - val_loss: 6.4720 - val_binary_accuracy: 0.9948 - val_IoU: 0.3674 - val_kaggle_IoU: 0.3701
#
# Epoch 00007: val_loss did not improve from 6.31893
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 8/99
# 20/20 [==============================] - 81s 4s/step - loss: 6.1211 - binary_accuracy: 0.9948 - IoU: 0.3835 - kaggle_IoU: 0.3828 - val_loss: 6.4521 - val_binary_accuracy: 0.9948 - val_IoU: 0.3684 - val_kaggle_IoU: 0.3710
#
# Epoch 00008: val_loss did not improve from 6.31893
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 9/99
# 20/20 [==============================] - 81s 4s/step - loss: 5.3557 - binary_accuracy: 0.9953 - IoU: 0.4241 - kaggle_IoU: 0.4238 - val_loss: 6.4468 - val_binary_accuracy: 0.9948 - val_IoU: 0.3687 - val_kaggle_IoU: 0.3713
#
# Epoch 00009: val_loss did not improve from 6.31893
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 10/99
# 20/20 [==============================] - 82s 4s/step - loss: 5.3478 - binary_accuracy: 0.9952 - IoU: 0.4274 - kaggle_IoU: 0.4267 - val_loss: 6.4397 - val_binary_accuracy: 0.9948 - val_IoU: 0.3691 - val_kaggle_IoU: 0.3717
#
# Epoch 00010: val_loss did not improve from 6.31893
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 11/99
# 20/20 [==============================] - 82s 4s/step - loss: 6.2625 - binary_accuracy: 0.9946 - IoU: 0.3803 - kaggle_IoU: 0.3791 - val_loss: 6.4372 - val_binary_accuracy: 0.9948 - val_IoU: 0.3692 - val_kaggle_IoU: 0.3718
#
# Epoch 00011: val_loss did not improve from 6.31893
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 00011: early stopping
# Epoch 1/99
# 20/20 [==============================] - 92s 5s/step - loss: 6.9996 - binary_accuracy: 0.9939 - IoU: 0.3393 - kaggle_IoU: 0.3386 - val_loss: 6.8837 - val_binary_accuracy: 0.9939 - val_IoU: 0.3479 - val_kaggle_IoU: 0.3547
#
# Epoch 00001: val_loss did not improve from 6.31893
# Epoch 2/99
# 20/20 [==============================] - 79s 4s/step - loss: 6.1529 - binary_accuracy: 0.9949 - IoU: 0.3837 - kaggle_IoU: 0.3838 - val_loss: 6.5535 - val_binary_accuracy: 0.9954 - val_IoU: 0.3644 - val_kaggle_IoU: 0.3632
#
# Epoch 00002: val_loss did not improve from 6.31893
# Epoch 3/99
# 20/20 [==============================] - 80s 4s/step - loss: 6.1464 - binary_accuracy: 0.9944 - IoU: 0.3852 - kaggle_IoU: 0.3838 - val_loss: 6.1987 - val_binary_accuracy: 0.9959 - val_IoU: 0.3804 - val_kaggle_IoU: 0.3782
#
# Epoch 00003: val_loss improved from 6.31893 to 6.19866, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 4/99
# 20/20 [==============================] - 80s 4s/step - loss: 6.3351 - binary_accuracy: 0.9946 - IoU: 0.3686 - kaggle_IoU: 0.3682 - val_loss: 6.2690 - val_binary_accuracy: 0.9952 - val_IoU: 0.3771 - val_kaggle_IoU: 0.3793
#
# Epoch 00004: val_loss did not improve from 6.19866
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 5/99
# 20/20 [==============================] - 79s 4s/step - loss: 6.4047 - binary_accuracy: 0.9949 - IoU: 0.3670 - kaggle_IoU: 0.3672 - val_loss: 7.1399 - val_binary_accuracy: 0.9934 - val_IoU: 0.3372 - val_kaggle_IoU: 0.3408
#
# Epoch 00005: val_loss did not improve from 6.19866
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 6/99
# 20/20 [==============================] - 80s 4s/step - loss: 6.2824 - binary_accuracy: 0.9944 - IoU: 0.3718 - kaggle_IoU: 0.3743 - val_loss: 6.3055 - val_binary_accuracy: 0.9949 - val_IoU: 0.3750 - val_kaggle_IoU: 0.3768
#
# Epoch 00006: val_loss did not improve from 6.19866
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 7/99
# 20/20 [==============================] - 80s 4s/step - loss: 6.1773 - binary_accuracy: 0.9946 - IoU: 0.3762 - kaggle_IoU: 0.3759 - val_loss: 6.2189 - val_binary_accuracy: 0.9950 - val_IoU: 0.3794 - val_kaggle_IoU: 0.3809
#
# Epoch 00007: val_loss did not improve from 6.19866
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 8/99
# 20/20 [==============================] - 80s 4s/step - loss: 6.3738 - binary_accuracy: 0.9947 - IoU: 0.3771 - kaggle_IoU: 0.3768 - val_loss: 6.2022 - val_binary_accuracy: 0.9951 - val_IoU: 0.3803 - val_kaggle_IoU: 0.3816
#
# Epoch 00008: val_loss did not improve from 6.19866
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 00008: early stopping
# Epoch 1/99
# 20/20 [==============================] - 91s 5s/step - loss: 6.6804 - binary_accuracy: 0.9946 - IoU: 0.3605 - kaggle_IoU: 0.3605 - val_loss: 7.0113 - val_binary_accuracy: 0.9941 - val_IoU: 0.3413 - val_kaggle_IoU: 0.3427
#
# Epoch 00001: val_loss did not improve from 6.19866
# Epoch 2/99
# 20/20 [==============================] - 78s 4s/step - loss: 7.0341 - binary_accuracy: 0.9944 - IoU: 0.3418 - kaggle_IoU: 0.3415 - val_loss: 6.1229 - val_binary_accuracy: 0.9959 - val_IoU: 0.3853 - val_kaggle_IoU: 0.3830
#
# Epoch 00002: val_loss improved from 6.19866 to 6.12295, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 3/99
# 20/20 [==============================] - 78s 4s/step - loss: 6.5715 - binary_accuracy: 0.9950 - IoU: 0.3605 - kaggle_IoU: 0.3601 - val_loss: 6.1220 - val_binary_accuracy: 0.9955 - val_IoU: 0.3847 - val_kaggle_IoU: 0.3831
#
# Epoch 00003: val_loss improved from 6.12295 to 6.12199, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 4/99
# 20/20 [==============================] - 77s 4s/step - loss: 5.7519 - binary_accuracy: 0.9947 - IoU: 0.4020 - kaggle_IoU: 0.4012 - val_loss: 5.9810 - val_binary_accuracy: 0.9951 - val_IoU: 0.3911 - val_kaggle_IoU: 0.3938
#
# Epoch 00004: val_loss improved from 6.12199 to 5.98099, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 5/99
# 20/20 [==============================] - 78s 4s/step - loss: 6.2039 - binary_accuracy: 0.9946 - IoU: 0.3788 - kaggle_IoU: 0.3784 - val_loss: 6.0179 - val_binary_accuracy: 0.9954 - val_IoU: 0.3879 - val_kaggle_IoU: 0.3891
#
# Epoch 00005: val_loss did not improve from 5.98099
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 6/99
# 20/20 [==============================] - 78s 4s/step - loss: 5.6252 - binary_accuracy: 0.9950 - IoU: 0.4104 - kaggle_IoU: 0.4097 - val_loss: 5.9812 - val_binary_accuracy: 0.9952 - val_IoU: 0.3891 - val_kaggle_IoU: 0.3911
#
# Epoch 00006: val_loss did not improve from 5.98099
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 7/99
# 20/20 [==============================] - 79s 4s/step - loss: 6.3393 - binary_accuracy: 0.9945 - IoU: 0.3724 - kaggle_IoU: 0.3723 - val_loss: 5.9943 - val_binary_accuracy: 0.9952 - val_IoU: 0.3887 - val_kaggle_IoU: 0.3906
#
# Epoch 00007: val_loss did not improve from 5.98099
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 8/99
# 20/20 [==============================] - 80s 4s/step - loss: 5.5862 - binary_accuracy: 0.9950 - IoU: 0.4099 - kaggle_IoU: 0.4098 - val_loss: 5.9420 - val_binary_accuracy: 0.9953 - val_IoU: 0.3914 - val_kaggle_IoU: 0.3930
#
# Epoch 00008: val_loss improved from 5.98099 to 5.94198, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 9/99
# 20/20 [==============================] - 81s 4s/step - loss: 5.8013 - binary_accuracy: 0.9950 - IoU: 0.4004 - kaggle_IoU: 0.3998 - val_loss: 5.8503 - val_binary_accuracy: 0.9954 - val_IoU: 0.3961 - val_kaggle_IoU: 0.3975
#
# Epoch 00009: val_loss improved from 5.94198 to 5.85033, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 10/99
# 20/20 [==============================] - 82s 4s/step - loss: 5.7129 - binary_accuracy: 0.9954 - IoU: 0.4035 - kaggle_IoU: 0.4034 - val_loss: 5.7847 - val_binary_accuracy: 0.9955 - val_IoU: 0.3996 - val_kaggle_IoU: 0.4007
#
# Epoch 00010: val_loss improved from 5.85033 to 5.78467, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 11/99
# 20/20 [==============================] - 83s 4s/step - loss: 5.6634 - binary_accuracy: 0.9947 - IoU: 0.4065 - kaggle_IoU: 0.4057 - val_loss: 5.7653 - val_binary_accuracy: 0.9956 - val_IoU: 0.4007 - val_kaggle_IoU: 0.4017
#
# Epoch 00011: val_loss improved from 5.78467 to 5.76533, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 12/99
# 20/20 [==============================] - 84s 4s/step - loss: 5.4905 - binary_accuracy: 0.9951 - IoU: 0.4190 - kaggle_IoU: 0.4175 - val_loss: 5.7744 - val_binary_accuracy: 0.9955 - val_IoU: 0.4002 - val_kaggle_IoU: 0.4015
#
# Epoch 00012: val_loss did not improve from 5.76533
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 13/99
# 20/20 [==============================] - 84s 4s/step - loss: 5.5833 - binary_accuracy: 0.9950 - IoU: 0.4137 - kaggle_IoU: 0.4135 - val_loss: 5.7640 - val_binary_accuracy: 0.9955 - val_IoU: 0.4007 - val_kaggle_IoU: 0.4021
#
# Epoch 00013: val_loss improved from 5.76533 to 5.76405, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 14/99
# 20/20 [==============================] - 84s 4s/step - loss: 5.6147 - binary_accuracy: 0.9952 - IoU: 0.4153 - kaggle_IoU: 0.4151 - val_loss: 5.7540 - val_binary_accuracy: 0.9955 - val_IoU: 0.4013 - val_kaggle_IoU: 0.4028
#
# Epoch 00014: val_loss improved from 5.76405 to 5.75403, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 15/99
# 20/20 [==============================] - 84s 4s/step - loss: 5.6005 - binary_accuracy: 0.9952 - IoU: 0.4077 - kaggle_IoU: 0.4064 - val_loss: 5.7459 - val_binary_accuracy: 0.9956 - val_IoU: 0.4017 - val_kaggle_IoU: 0.4031
#
# Epoch 00015: val_loss improved from 5.75403 to 5.74590, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 16/99
# 20/20 [==============================] - 84s 4s/step - loss: 5.4841 - binary_accuracy: 0.9953 - IoU: 0.4152 - kaggle_IoU: 0.4147 - val_loss: 5.7428 - val_binary_accuracy: 0.9956 - val_IoU: 0.4019 - val_kaggle_IoU: 0.4032
#
# Epoch 00016: val_loss improved from 5.74590 to 5.74280, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 17/99
# 20/20 [==============================] - 84s 4s/step - loss: 5.6548 - binary_accuracy: 0.9953 - IoU: 0.4099 - kaggle_IoU: 0.4093 - val_loss: 5.7252 - val_binary_accuracy: 0.9956 - val_IoU: 0.4029 - val_kaggle_IoU: 0.4043
#
# Epoch 00017: val_loss improved from 5.74280 to 5.72520, saving model to checkpoints/seg_model_weights.best.hdf5
# Epoch 18/99
#  6/20 [========>.....................] - ETA: 47s - loss: 6.8401 - binary_accuracy: 0.9953 - IoU: 0.3457 - kaggle_IoU: 0.3435

# %%
def show_loss(loss_history):
    epochs = np.concatenate([mh.epoch for mh in loss_history])
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(22, 10))
    
    _ = ax1.plot(epochs, np.concatenate([mh.history['loss'] for mh in loss_history]), 'b-',
                 epochs, np.concatenate([mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')
    
    _ = ax2.plot(epochs, np.concatenate([mh.history['binary_accuracy'] for mh in loss_history]), 'b-',
                 epochs, np.concatenate([mh.history['val_binary_accuracy'] for mh in loss_history]), 'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('Binary Accuracy (%)')

show_loss(loss_history)

# %%
seg_model.load_weights(WEIGHT_PATH)
seg_model.save(os.path.join(CHECKPOINTS_DIR, '{}.h5'.format(MODEL_NAME)))

# %%
pred_y = seg_model.predict(valid_x)
print(pred_y.shape, pred_y.min(axis=0).max(), pred_y.max(axis=0).min(), pred_y.mean())

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 6))
ax.hist(pred_y.ravel(), np.linspace(0, 1, 20))
ax.set_xlim(0, 1)
ax.set_yscale('log', nonposy='clip')

# %%
if IMG_SCALING is not None:
    fullres_model = models.Sequential()
    fullres_model.add(layers.AvgPool2D(IMG_SCALING, input_shape = (None, None, 3)))
    fullres_model.add(seg_model)
    fullres_model.add(layers.UpSampling2D(IMG_SCALING))
else:
    fullres_model = seg_model
fullres_model.save(os.path.join(CHECKPOINTS_DIR, '{}.h5'.format(FULL_RES_MODEL_NAME)))

# %%
def predict(img, path=TEST_DIR, thresh=0.5):
    c_img = cv2.imread(os.path.join(path, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    cur_seg = fullres_model.predict(c_img)[0]
    cur_seg[cur_seg > thresh] = 1
    cur_seg[cur_seg < thresh] = 0
    return cur_seg, c_img

## Get a sample of each group of ship count
samples = valid_df.groupby('ships').apply(lambda x: x.sample(1))
fig, m_axs = plt.subplots(samples.shape[0], 4, figsize = (15, samples.shape[0]*4))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2, ax3, ax4), c_img_name in zip(m_axs, samples.ImageId.values):
    first_seg, first_img = predict(c_img_name, TRAIN_DIR)
    ax1.imshow(first_img[0])
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(first_seg[:, :, 0])
    ax2.set_title('Model Prediction')
    reencoded = masks_as_color(multi_rle_encode(first_seg[:, :, 0]))
    ax3.imshow(reencoded)
    ax3.set_title('Prediction Re-encoded')
    ground_truth = masks_as_color(df.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels'])
    ax4.imshow(ground_truth)
    ax4.set_title('Ground Truth')
  
    
    
# fig.savefig('validation.png')

# %% [markdown]
# # 5. SUBMISSION

# %%
test_paths = np.array(os.listdir(TEST_DIR))
print(len(test_paths), 'test images found')

# %%
from tqdm import tqdm_notebook

def pred_encode(img, **kwargs):
    cur_seg, _ = predict(img)
    cur_rles = multi_rle_encode(cur_seg, **kwargs)
    return [[img, rle] for rle in cur_rles if rle is not None]

out_pred_rows = []
for c_img_name in tqdm_notebook(test_paths[:30000]): ## only a subset as it takes too long to run
    out_pred_rows += pred_encode(c_img_name, min_max_threshold=1.0)

# %%
sub = pd.DataFrame(out_pred_rows)
sub.columns = ['ImageId', 'EncodedPixels']
sub = sub[sub.EncodedPixels.notnull()]
sub.head()

# %%
## let's see what we got
TOP_PREDICTIONS=5
fig, m_axs = plt.subplots(TOP_PREDICTIONS, 2, figsize = (9, TOP_PREDICTIONS*5))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2), c_img_name in zip(m_axs, sub.ImageId.unique()[:TOP_PREDICTIONS]):
    c_img = imread(os.path.join(test_image_dir, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    ax1.imshow(c_img[0])
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(masks_as_color(sub.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels']))
    ax2.set_title('Prediction')

# %%
sub1 = pd.read_csv(os.path.join(INPUT_DIR, 'sample_submission.csv'))
sub1 = pd.DataFrame(np.setdiff1d(sub1['ImageId'].unique(), sub['ImageId'].unique(), assume_unique=True), columns=['ImageId'])
sub1['EncodedPixels'] = None
print(len(sub1), len(sub))

sub = pd.concat([sub, sub1])
print(len(sub))
sub.to_csv('submission.csv', index=False)
sub.head()
